# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
insert_costs = np.load('insert_costs.npy')
upsert_costs = np.load('upsert_costs.npy')
query_costs = np.load('query_costs.npy')
print(insert_costs.shape, upsert_costs.shape, query_costs.shape)
# Out:
# (200,) (200,) (200,)

# %%
plt.plot(insert_costs)
plt.title('insert_cost')
plt.show()
plt.plot(upsert_costs)
plt.title('upsert_cost')
plt.show()
plt.plot(query_costs)
plt.title('query_cost')
plt.show()
